# %%
import numpy as np
import pandas as pd

from scipy.spatial.transform import Rotation as R

import seaborn as sns
sns.set_style("whitegrid")

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('pose.txt', sep=' ',names=['time','x','y','z','quatX','quatY','quatZ','quatW'])


subset = data  #[ data['time'] > 57 ]
print(subset.head())
# Out:
#        time             x             y         z         quatX         quatY  \
# 0  0.000000  4.066271e-07  2.123548e-07  0.000001  2.540615e-08 -4.416962e-08
# 1  0.045709  3.424840e-03 -5.371190e-04  0.006099  7.479463e-05 -7.615877e-05
# 2  0.115616  3.546868e-03 -5.596446e-04  0.006287  7.423881e-05 -8.104424e-05
# 3  0.183280  4.253257e-03 -1.917480e-03  0.009507  2.174308e-04 -2.263997e-07
# 4  0.253434  4.253257e-03 -1.917480e-03  0.009507  2.174308e-04 -2.263997e-07
#
#           quatZ  quatW
# 0 -1.497157e-08    1.0
# 1  1.215051e-06    1.0
# 2  5.579350e-07    1.0
# 3  2.636337e-04    1.0
# 4  2.636337e-04    1.0

# %%
## Apply rotation

# rot = R.from_euler('y', 0, degrees=True)

# def rotate( r ):
#     v = rot.apply( [r['x'], r['y'], r['z']])
#     return pd.Series( {'x': v[0], 'y':v[1], 'z':v[2]})
    

# rotated = subset.apply( rotate,axis=1 )
# rotated['time'] = subset['time']

# print(rotated.head(10))

# %%
# def colormap( z ):
#     if t > 57:
#         return 'r'
#     else:
#         return 'b'

# color = data['time'].apply( colormap  )

plot_data = subset

colormap = sns.light_palette((0,0,1.0), as_cmap=True)

plt.figure(figsize=(15,12))
plt.scatter( plot_data['x'], plot_data['y'], c=plot_data['time'], cmap=colormap )
plt.xlabel('x')
plt.ylabel('y')
cbar = plt.colorbar()
cbar.set_label("Z")

fig,ax = plt.subplots(3,1, figsize=(12,12))

ylim = [-2.5,6]

ax[0].scatter( plot_data['time'], plot_data['x'], c=plot_data['z'], cmap=colormap)
# ax[0].set_xlabel('time (s)')
ax[0].set_ylim(ylim)
ax[0].set_ylabel('x')

ax[1].scatter( plot_data['time'], plot_data['y'], c=plot_data['z'], cmap=colormap)
# ax[1].set_xlabel('time (s)')
ax[1].set_ylim(ylim)
ax[1].set_ylabel('y')

ax[2].scatter( plot_data['time'], plot_data['z'], c=plot_data['z'], cmap=colormap)
ax[2].set_xlabel('time (s)')
ax[2].set_ylabel('z')
# Out:
# Text(0, 0.5, 'z')

# %%
from mpl_toolkits import mplot3d

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")

ax.scatter3D( data['x'], data['y'], data['z'])

plt.show()
